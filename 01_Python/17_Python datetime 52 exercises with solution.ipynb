# %% [markdown]
# # <center>Python datetime [52 exercises with solution]</center>

# %% [markdown]
# ### 1. Write a Python script to display the various Date Time formats -
#
# a) Current date and time
# b) Current year
# c) Month of year
# d) Week number of the year
# e) Weekday of the week
# f) Day of year
# g) Day of the month
# h) Day of week

# %% [markdown]
# ### 2. Write a Python program to determine whether a given year is a leap year.

# %% [markdown]
# #### Problem's Source: [https://www.w3resource.com/python-exercises/date-time-exercise/](https://www.w3resource.com/python-exercises/date-time-exercise/)

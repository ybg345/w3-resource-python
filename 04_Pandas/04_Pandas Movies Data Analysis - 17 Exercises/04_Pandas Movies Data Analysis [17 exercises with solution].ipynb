# %% [markdown]
# # <center> Pandas Movies Data Analysis [17 exercises with solution]</center>

# %% [markdown]
# **Problems List [learned new, see again]-**
# - *Problem 6: Second Solution*
# - Problem 11
# - *Problem 15*

# %%
# Importing libraries:

import numpy as np
import pandas as pd

# %%
# Importing file:

movies_filepath = 'movies_metadata.csv'
movies_mdata = pd.read_csv(movies_filepath)

# %% [markdown]
# ## 1. Write a Python Pandas program to get the columns of the DataFrame (movies_metadata.csv file).

# %%
movies_mdata.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# ## 2. Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file)including data types and memory usage.

# %%
movies_mdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
# adult                    50 non-null bool
# belongs_to_collection    10 non-null object
# budget                   50 non-null int64
# genres                   50 non-null object
# homepage                 5 non-null object
# id                       50 non-null int64
# imdb_id                  50 non-null object
# original_language        50 non-null object
# original_title           50 non-null object
# overview                 49 non-null object
# popularity               50 non-null float64
# poster_path              50 non-null object
# production_companies     50 non-null object
# production_countries     50 non-null object
# release_date             50 non-null object
# revenue                  50 non-null int64
# runtime                  50 non-null float64
# spoken_languages         50 non-null object
# status                   50 non-null object
# ...

# %% [markdown]
# ## 3. Write a Pandas program to get the details of the thrid movie of the DataFrame (movies_metadata.csv file).

# %%
print('Details of third movie:\n')
print(movies_mdata.iloc[2])
# Out:
# Details of third movie:
#
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# ## 4. Write a Pandas program to count the number of rows and columns of the DataFrame (movies_metadata.csv file).

# %%
print('Number of rows in the dataframe: {}'.format(movies_mdata.shape[0]))
print('Number of columns in the dataframe: {}'.format(movies_mdata.shape[1]))
# Out:
# Number of rows in the dataframe: 50
# Number of columns in the dataframe: 24

# %% [markdown]
# ## 5. Write a Pandas program to get the details of the columns title and genres of the DataFrame.

# %%
movies_mdata[['title', 'genres']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# 5                             Heat
# 6                          Sabrina
# 7                     Tom and Huck
# 8                     Sudden Death
# 9                        GoldenEye
# 10          The American President
# 11     Dracula: Dead and Loving It
# 12                           Balto
# 13                           Nixon
# 14                Cutthroat Island
# 15                          Casino
# 16           Sense and Sensibility
# 17                      Four Rooms
# 18  Ace Ventura: When Nature Calls
# 19                     Money Train
# 20                      Get Shorty
# 21                         Copycat
# 22                       Assassins
# 23                          Powder
# 24               Leaving Las Vegas
# ...

# %% [markdown]
# ## 6. Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'.

# %%
movies_mdata[movies_mdata['title'] == 'Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ...  release_date  \
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
#
#   revenue runtime                          spoken_languages    status  \
# 2       0   101.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 2          6.5         92
#
# [1 rows x 24 columns]

# %%
# Solution 2:

movies_mdata.set_index('title').loc['Grumpier Old Men']
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# ## 7. Write a Pandas program to get the details of  fifth movie of the DataFrame.

# %%
movies_mdata.iloc[4]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                         8.38752
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %% [markdown]
# ## 8. Write a Pandas program to create a smaller dataframe with a subset of all features.

# %%
small_df = movies_mdata[['title', 'release_date', 'budget', 'revenue', 'runtime']]
small_df.head()
# Out:
#                          title release_date    budget    revenue  runtime
# 0                    Toy Story   1995-10-30  30000000  373554033     81.0
# 1                      Jumanji   1995-12-15  65000000  262797249    104.0
# 2             Grumpier Old Men   1995-12-22         0          0    101.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911    106.0

# %% [markdown]
# ## 9. Write a Pandas program to display the first 10 rows of the DataFrame.

# %%
# Solution 1: 
# movies_mdata.head(10)

# Solution 2:
movies_mdata.iloc[:10]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %% [markdown]
# ## 10. Write a Pandas program to sort the DataFrame based on release_date.

# %%
movies_mdata.sort_values('release_date')
# Out:
#     adult                              belongs_to_collection    budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 29  False                                                NaN         0
# 48  False                                                NaN         0
# 28  False                                                NaN  18000000
# 44  False                                                NaN  20000000
# 47  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 33  False  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
# 38  False                                                NaN  12000000
# 49  False                                                NaN   6000000
# 30  False                                                NaN         0
# 43  False  {'id': 9818, 'name': 'Mortal Kombat Collection...  18000000
# 46  False                                                NaN  33000000
# ...

# %% [markdown]
# ## 11. Write a Pandas program to access those movies, released after 1995-01-01.

# %%
small_df[movies_mdata['release_date'] > '1995-01-01']
# Out:
#                              title release_date    budget    revenue  runtime
# 0                        Toy Story   1995-10-30  30000000  373554033     81.0
# 1                          Jumanji   1995-12-15  65000000  262797249    104.0
# 2                 Grumpier Old Men   1995-12-22         0          0    101.0
# 3                Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 4      Father of the Bride Part II   1995-02-10         0   76578911    106.0
# 5                             Heat   1995-12-15  60000000  187436818    170.0
# 6                          Sabrina   1995-12-15  58000000          0    127.0
# 7                     Tom and Huck   1995-12-22         0          0     97.0
# 8                     Sudden Death   1995-12-22  35000000   64350171    106.0
# 9                        GoldenEye   1995-11-16  58000000  352194034    130.0
# 10          The American President   1995-11-17  62000000  107879496    106.0
# ...

# %% [markdown]
# ## 12. Write a Pandas program to sort movies on runtime in descending order.

# %%
small_df.sort_values('runtime', ascending = False).head()
# Out:
#                     title release_date    budget    revenue  runtime
# 13                  Nixon   1995-12-22  44000000   13681765    192.0
# 15                 Casino   1995-11-22  52000000  116112375    178.0
# 5                    Heat   1995-12-15  60000000  187436818    170.0
# 16  Sense and Sensibility   1995-12-13  16500000  135000000    136.0
# 22              Assassins   1995-10-06  50000000   30303072    132.0

# %% [markdown]
# ## 13. Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million.

# %%
small_df[(small_df['revenue'] > 20000000) & (small_df['budget'] < 10000000)]
# Out:
#                           title release_date   budget    revenue  runtime
# 4   Father of the Bride Part II   1995-02-10        0   76578911    106.0
# 24            Leaving Las Vegas   1995-10-27  3600000   49800000    112.0
# 30              Dangerous Minds   1995-08-11        0  180000000     99.0
# 49           The Usual Suspects   1995-07-19  6000000   23341568    106.0

# %% [markdown]
# ## 14. Write a Pandas program to get the longest runtime and shortest runtime.

# %%
print('Longest runtime: {}'.format(movies_mdata['runtime'].max()))
print('Shortest runtime: {}'.format(movies_mdata['runtime'].min()))
# Out:
# Longest runtime: 192.0
# Shortest runtime: 50.0

# %% [markdown]
# ## 15. Write a Pandas program to compute the calculate the number of votes garnered by the 70% movie.

# %%
movies_mdata['vote_count'].quantile(.7)
# Out:
# 402.6999999999999

# %% [markdown]
# ## 16. Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes.

# %%
movies_mdata[(movies_mdata['runtime'] > 30) & (movies_mdata['runtime'] < 360)][['title', 'runtime']]
# Out:
#                              title  runtime
# 0                        Toy Story     81.0
# 1                          Jumanji    104.0
# 2                 Grumpier Old Men    101.0
# 3                Waiting to Exhale    127.0
# 4      Father of the Bride Part II    106.0
# 5                             Heat    170.0
# 6                          Sabrina    127.0
# 7                     Tom and Huck     97.0
# 8                     Sudden Death    106.0
# 9                        GoldenEye    130.0
# 10          The American President    106.0
# 11     Dracula: Dead and Loving It     88.0
# 12                           Balto     78.0
# 13                           Nixon    192.0
# 14                Cutthroat Island    119.0
# 15                          Casino    178.0
# 16           Sense and Sensibility    136.0
# 17                      Four Rooms     98.0
# 18  Ace Ventura: When Nature Calls     90.0
# 19                     Money Train    103.0
# ...

# %% [markdown]
# ## 17. Write a Pandas program to display the movies (title, number of votes) that received specified number of votes.

# %%
small_df = movies_mdata[['title', 'vote_count']]
n = 500
small_df[small_df['vote_count'] >= n]
# Out:
#                              title  vote_count
# 0                        Toy Story        5415
# 1                          Jumanji        2413
# 5                             Heat        1886
# 9                        GoldenEye        1194
# 15                          Casino        1343
# 17                      Four Rooms         539
# 18  Ace Ventura: When Nature Calls        1128
# 31                  Twelve Monkeys        2470
# 33                            Babe         756
# 38                        Clueless         828
# 46                           Se7en        5915
# 47                      Pocahontas        1509
# 49              The Usual Suspects        3334

# %% [markdown]
# #### Problem's Source: [https://www.w3resource.com/python-exercises/pandas/movies/index.php](https://www.w3resource.com/python-exercises/pandas/movies/index.php)
